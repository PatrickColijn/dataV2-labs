# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
cdd = pd.read_csv('CDD.csv', sep = "\t")
cdd.head()
# Out:
#   EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0       Disaster     Natural  Meteorological - Hydrological
# 1       Disaster     Natural  Meteorological - Hydrological
# 2       Disaster     Natural  Meteorological - Hydrological
# 3       Disaster     Natural                     Biological
# 4       Incident  Technology            Hazardous Chemicals
#
#                     EVENT TYPE                                 PLACE  \
# 0  Storm - Unspecified / Other                   Christmas Island NS
# 1                 Winter Storm  Nova Scotia and Prince Edward Island
# 2                        Flood             Red Earth First Nation SK
# 3                     Epidemic              Alberta and Saskatchewan
# 4         Leak / Spill Release                   Seaforth Channel BC
#
#          EVENT START DATE                                           COMMENTS  \
# 0  25/12/2016 12:00:00 AM  Christmas Island NS, December 25, 2016. Reside...
# ...

# %%
# 1. Print the correlation matrix
cdd.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %%
# 2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(cdd.corr())

# %%
# 3. Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is 
# almost zero and one pair that is negatively correlated. In each case write down an explanation why we see  
# this correlation

'''
High correlation: Fatalities vs Injured / Infected -> If someone is infected or injured by a disaster there
will be a chance he/she will not survive this. If he/she is not injured or infected it is impossible this persons
from this.

(almost) Zero correlation: Magnitude & FEDERAL DFAA PAYMENTS -> There is no correlation between the payments of 
the federal DFAA paments and the severity of the disasters. 

Negative correlation: OGD COSTS and UTILITY - PEOPLE AFFECTED -> if more people are effected the costs will per
person will most likely decrease'''
# Out:
# '\nHigh correlation: Fatalities vs Injured / Infected -> If someone is infected or injured by a disaster there\nwill be a chance he/she will not survive this. If he/she is not injured or infected it is impossible this persons\nfrom this.\n\n(almost) Zero correlation: Magnitude & FEDERAL DFAA PAYMENTS -> There is no correlation between the payments of \nthe federal DFAA paments and the severity of the disasters. \n\nNegative correlation: OGD COSTS and UTILITY - PEOPLE AFFECTED -> if more people are effected the costs will per\n\n'

# %%
#4. Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you 
# selected. Does what you see confirm your ideas? Describe in a comment.

'''All correlations chosen have been influenced because of a / multiple massive outlier(s). Therefore, the correlation might be (most likely) not be correct'''
# Out:
# 'All correlations chosen have been influenced because of a / multiple massive outlier(s). Therefore, the correlation might be (most likely) not be correct'

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(cdd[['FATALITIES','INJURED / INFECTED']])

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(cdd[['MAGNITUDE','FEDERAL DFAA PAYMENTS']])
# Out:
# 'Because of a massive outlier the correlation the correlation might be (most likely) not be correct'

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(cdd[['OGD COSTS', 'UTILITY - PEOPLE AFFECTED']])
