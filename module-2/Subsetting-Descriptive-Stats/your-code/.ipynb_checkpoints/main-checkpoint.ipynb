# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv('../Temp_states.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.describe()
# Out:
#        Temperature
# count     7.000000
# mean     15.158730
# std       6.695265
# min       3.333333
# 25%      11.944444
# 50%      17.222222
# 75%      19.722222
# max      22.222222

# %%
"""
City and data are nominal data and temperature is a range value 
"""
# Out:
# '\nCity and data are nominal data and temperature is a range value \n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp_NY = temp.loc[temp['State'] == 'New York']
temp_NY
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp_NY.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp_above15 = temp.loc[(temp['Temperature'] >= 15)]
temp_above15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp_above15['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp_15_20 = temp.loc[(temp['Temperature'] >= 15) & (temp['Temperature'] <= 20)]
temp_15_20
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
temp.groupby('State').agg(['mean', 'std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('../Employee.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %%
"""
Employee data is indexed on zero.
* Includes names, department, education, gender, title, years and salary (prob in thousand p/year)
"""
# Out:
# '\nEmployee data is indexed on zero.\n* Includes names, department, education, gender, title, years and salary (prob in thousand p/year)\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
mean_salary = round(employees['Salary'].mean())
print("The mean salary of the company is ${}.000".format(mean_salary))
# Out:
# The mean salary of the company is $49.000

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
max_salary = round(employees['Salary'].max())
print("The max salary of the company is ${}.000".format(max_salary))
# Out:
# The max salary of the company is $70.000

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
min_salary = round(employees['Salary'].min())
print("The max salary of the company is ${}.000".format(min_salary))
# Out:
# The max salary of the company is $30.000

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees.loc[(employees['Salary'] == min_salary)]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees.loc[(employees['Name'] == 'David')]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
salary_david = int(employees['Salary'].loc[(employees['Name'] == 'David')].values)
print("The salary of David is: ${}.000".format(salary_david))
# Out:
# The salary of David is: $30.000

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
associates = employees.loc[(employees['Title'] == 'associate')]
associates
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here
employees.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees.loc[(employees['Title'] == 'associate') & (employees['Salary'] >= 55)]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby('Years').agg(['mean'])
# Out:
#           Salary
#             mean
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby('Title').agg(['mean'])
# Out:
#           Years     Salary
#            mean       mean
# Title
# VP         8.00  70.000000
# analyst    2.25  32.500000
# associate  4.00  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees['Salary'].loc[(employees['Gender'] == 'M')].mean() == employees['Salary'].loc[(employees['Gender'] == 'F')].mean()
# Out:
# False

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees_dp = employees.groupby('Department').agg(['min', 'mean', 'max'])
employees_dp
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
employees_dp['range'] = employees_dp.apply(lambda row: row.Salary['max'] - row.Salary['min'], axis = 1)
employees_dp
# Out:
#            Years               Salary            range
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70  40.0
# IT             1  4.500000   8     30  48.75  70  40.0
# Sales          2  2.500000   3     55  55.00  55   0.0

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv('../Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.columns
orders.shape
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
"""
This data set contains information regarding almost 400k orders 

Dataframe has the following shape: (397924, 14) -> meaning that there are 14 columns and 397.924 rows

Dataframe has the following columns:'InvoiceNo', 'StockCode', 'year', 'month', 'day', 'hour','Description',
'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'amount_spent'

"""
# Out:
# "\nThis data set contains information regarding almost 400k orders \n\nDataframe has the following shape: (397924, 14) -> meaning that there are 14 columns and 397.924 rows\n\nDataframe has the following columns:'InvoiceNo', 'StockCode', 'year', 'month', 'day', 'hour','Description',\n'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'amount_spent'\n\n"

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
round(orders['amount_spent'].mean(), 2)
# Out:
# 22.39

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders['amount_spent'].describe()
# Out:
# count    397924.000000
# mean         22.394749
# std         309.055588
# min           0.000000
# 25%           4.680000
# 50%          11.800000
# 75%          19.800000
# max      168469.600000
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders_c_spain = orders.loc[(orders['Country'] == 'Spain')].groupby('CustomerID').agg(['mean'])
orders_c_spain
# Out:
#                Unnamed: 0      InvoiceNo         year      month       day  \
#                      mean           mean         mean       mean      mean
# CustomerID
# 12354       166295.500000  550911.000000  2011.000000   4.000000  4.000000
# 12417       171232.000000  551398.000000  2011.000000   4.000000  4.000000
# 12421       262510.622222  559281.933333  2011.000000   6.266667  3.955556
# 12442       531425.500000  580955.000000  2011.000000  12.000000  2.000000
# 12445       478970.500000  577125.000000  2011.000000  11.000000  4.000000
# 12448       420313.500000  572886.000000  2011.000000  10.000000  3.000000
# 12450       237307.750000  557764.250000  2011.000000   6.250000  6.000000
# 12454       398633.000000  571255.000000  2011.000000  10.000000  5.000000
# 12455       289392.520833  562199.083333  2011.000000   7.625000  3.250000
# 12462       227907.209677  555628.580645  2011.000000   5.193548  2.290323
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
orders_c_spain.count()
# Out:
# Unnamed: 0    mean    30
# InvoiceNo     mean    30
# year          mean    30
# month         mean    30
# day           mean    30
# hour          mean    30
# Quantity      mean    30
# UnitPrice     mean    30
# amount_spent  mean    30
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
customer_50 = orders[['CustomerID', 'Quantity']].groupby('CustomerID').agg({'Quantity':'sum'})
customer_50.loc[(customer_50['Quantity'] >= 50)]
# Out:
#             Quantity
# CustomerID
# 12346          74215
# 12347           2458
# 12348           2341
# 12349            631
# 12350            197
# ...              ...
# 18278             66
# 18281             54
# 18282            103
# 18283           1397
# 18287           1586
#
# [4098 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders_50_spain = orders.loc[(orders['Country'] == 'Spain') & (orders['Quantity'] >= 50)]
orders_50_spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91157       136769     547972     20727  2011      3    1    16
# 91158       136770     547972     20725  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
free_orders = orders.loc[(orders['amount_spent'] == 0)]
free_orders.head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
# 29080       47068     540372     22090  2011      1    4    16
# 29082       47070     540372     22553  2011      1    4    16
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
# 29080       paper bunting retrospot        24  2011-01-06 16:41:00        0.0
# 29082        plasters in tin skulls        24  2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
lunch_bag = orders.loc[(orders['Description'].str.match('^lunch bag') == True)]
lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
lunch_bag_2011 = orders.loc[(orders['Description'].str.match('^lunch bag') == True) & (orders['InvoiceDate']  > '2011-1-1 00:00:00')]
lunch_bag_2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 266543      370956     569205     20728  2011     10    7    10
# 266553      370966     569205     22384  2011     10    7    10
# 266561      370974     569205     23207  2011     10    7    10
# 266563      370976     569205     20727  2011     10    7    10
# 266564      370977     569205     22382  2011     10    7    10
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 266543          lunch bag cars blue        10  2011-10-02 10:55:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
freq_dist_spain = orders['amount_spent'].loc[(orders['Country'] == 'Spain')].value_counts()
plt.hist(freq_dist_spain, bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Select all orders made in the month of August.

# %%
# your code here
orders_august = orders.loc[(orders['month'] == 8)]
orders_august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
x = orders_august['Quantity'].value_counts()
plt.hist(freq_dist_spain, bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders[['Country','amount_spent']].groupby('Country').mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders.loc[(orders['UnitPrice'].idxmax())]
# Out:
# Unnamed: 0                   173382
# InvoiceNo                    551697
# StockCode                      POST
# year                           2011
# month                             5
# day                               2
# hour                             13
# Description                 postage
# Quantity                          1
# InvoiceDate     2011-05-03 13:46:00
# UnitPrice                   8142.75
# CustomerID                    16029
# Country              United Kingdom
# amount_spent                8142.75
# Name: 118352, dtype: object

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders[['year','amount_spent']].groupby('year').mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
