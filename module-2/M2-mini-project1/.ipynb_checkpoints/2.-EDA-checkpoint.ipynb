# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         color       clarity         depth         table  \
# count  40450.000000  40450.000000  40450.000000  40450.000000  40450.000000
# mean       0.588601      3.561706      3.115352     61.757629     57.347431
# std        0.271197      1.677461      1.693984      1.426422      2.254782
# min        0.200000      0.000000      0.000000     43.000000     43.000000
# 25%        0.340000      2.000000      2.000000     61.100000     56.000000
# 50%        0.520000      4.000000      3.000000     61.800000     57.000000
# 75%        0.760000      5.000000      4.000000     62.500000     59.000000
# max        2.060000      6.000000      7.000000     79.000000     79.000000
#
#               price             x             y             z
# count  40450.000000  40450.000000  40450.000000  40450.000000
# mean    2012.891545      5.255778      5.260286      3.247211
# std     1421.342841      0.795468      0.788854      0.494807
# min      326.000000      3.730000      3.680000      2.060000
# 25%      810.000000      4.510000      4.510000      2.780000
# 50%     1571.000000      5.170000      5.170000      3.190000
# 75%     3001.000000      5.870000      5.870000      3.620000
# max     5324.000000      8.110000      8.070000      5.120000

# %%
#your comments here
'''
Variabilility is the statistical dispersion (spreiding) to which data points in a statistical
distribution or data set diverge --vary-- from the average values, as well as the extent
to which these data points differ from each other. 

Price has a high standard relatively high standard deviation compared to the other, although
its mean is much higher than other values.
'''
# Out:
# '\nVariabilility is the statistical dispersion (spreiding) to which data points in a statistical\ndistribution or data set diverge --vary-- from the average values, as well as the extent\nto which these data points differ from each other. \n'

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
''' 

1. I think color will be one of the most deterministic value due to the fact that the
color of the rock defines it rarity. 
 - H1: Color is highly correlated with price and has a positive relationship
2. Secondly, I think clarity plays a big role and is probably associated with the quality 
of the stone
 - H2: Clarity has a positive effect on prices
3. After that the size and weight are an multiplying factor on the price
 - H3: Size and weight are positively correlated with price

'''
# Out:
# ' \n\n1. I think color will be one of the most deterministic value due to the fact that the\ncolor of the rock defines it rarity. \n - H1: Color is highly correlated with price and has a positive relationship\n2. Secondly, I think clarity plays a big role and is probably associated with the quality \nof the stone\n - H2: Clarity has a positive effect on prices\n3. After that the size and weight are an multiplying factor on the price\n - H3: Size and weight are positively correlated with price\n\n'

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
diamonds.head()
# Out:
#    carat      cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    Ideal      5        1   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium      5        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good      5        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good      0        1   63.3   58.0    335  4.34  4.35  2.75

# %%
#your code here
color = diamonds.groupby('color').agg('mean')
color
# Out:
#           carat   clarity      depth      table        price         x  \
# color
# 0      0.789546  2.792074  61.924871  57.614934  2481.349225  5.794595
# 1      0.681982  3.187482  61.925573  57.335429  2225.406967  5.503897
# 2      0.645521  3.140706  61.853600  57.398269  2236.677570  5.400537
# 3      0.555601  3.509499  61.774587  57.193104  1851.291142  5.162649
# 4      0.579122  3.146358  61.691666  57.368547  2030.942776  5.239984
# 5      0.541435  3.004246  61.661669  57.427620  1871.003518  5.129096
# 6      0.538501  2.697848  61.705140  57.296923  1921.584208  5.125239
#
#               y         z
# color
# 0      5.793854  3.587622
# 1      5.508519  3.409459
# 2      5.401691  3.340556
# 3      5.168036  3.191549
# 4      5.245938  3.234510
# 5      5.134589  3.163666
# 6      5.130121  3.163511

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
'''
You see a negative relationship between price and color which is different from what I
expected at first. 
'''

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
color.plot()
sns.distplot(diamonds['color'],kde = False)
plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
#your comments here
'''
The plot shows that the mean prive grouped by colors are actually quite the same.
'''

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
carat = diamonds.groupby('carat').agg('mean')
carat
# Out:
#           color   clarity      depth      table        price         x  \
# carat
# 0.20   5.166667  2.833333  61.100000  59.333333   365.166667  3.786667
# 0.21   5.444444  2.666667  60.511111  58.444444   380.222222  3.874444
# 0.22   4.800000  2.600000  61.620000  60.400000   391.400000  3.898000
# 0.23   4.518771  4.901024  61.426621  58.034130   486.143345  3.946382
# 0.24   4.185039  4.972441  61.599213  57.488189   505.185039  3.990157
# ...         ...       ...        ...        ...          ...       ...
# 1.74   2.000000  0.000000  63.200000  55.000000  4677.000000  7.620000
# 1.83   0.000000  0.000000  70.000000  58.000000  5083.000000  7.340000
# 1.95   2.000000  0.000000  60.300000  59.000000  5045.000000  8.100000
# 2.00   0.000000  0.000000  61.500000  59.000000  5051.000000  8.110000
# 2.06   0.000000  0.000000  61.200000  58.000000  5203.000000  8.100000
#
#               y         z
# carat
# 0.20   3.753333  2.303333
# 0.21   3.837778  2.332222
# 0.22   3.848000  2.386000
# 0.23   3.973379  2.431468
# 0.24   4.019331  2.465591
# ...         ...       ...
# 1.74   7.590000  4.800000
# 1.83   7.280000  5.120000
# 1.95   8.050000  4.870000
# 2.00   8.060000  4.970000
# 2.06   8.070000  4.950000
#
# [142 rows x 8 columns]

# %%
#your comments
'''
Based on the carat we see a strong positive relationship with price. This will most likely 
mean that the higher the number of carat, the higher the price will be! 
'''

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
carat.plot()
sns.distplot(diamonds['carat'],kde = False)
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
table = diamonds.groupby('table').agg('mean')
table
# Out:
#         carat  color  clarity  depth    price        x        y        z
# table
# 43.0   1.0400   1.00     4.00  62.90  4997.00  6.45000  6.41000  4.04000
# 44.0   0.2900   5.00     4.00  62.80   474.00  4.20000  4.24000  2.65000
# 49.0   0.6500   3.00     3.00  64.25  2290.50  5.35500  5.32000  3.42500
# 50.0   1.0200   4.00     2.00  61.80  4227.00  6.59000  6.51000  4.05000
# 50.1   0.9400   2.00     1.00  66.00  3353.00  6.13000  6.17000  4.06000
# ...       ...    ...      ...    ...      ...      ...      ...      ...
# 70.0   0.7175   2.75     2.75  58.15  2189.25  5.89875  5.79375  3.40125
# 71.0   0.6800   3.00     2.00  58.00  1633.00  5.85000  5.70000  3.35000
# 73.0   0.6025   4.50     3.25  68.90  2406.50  5.52000  5.46500  3.74500
# 76.0   0.7900   3.00     2.00  65.30  2362.00  5.52000  5.13000  3.35000
# 79.0   0.8100   4.00     1.00  68.80  2301.00  5.26000  5.20000  3.58000
#
# [125 rows x 8 columns]

# %%
#your comments here
'''
It is not really possible to find a relationship between table and price
'''
# Out:
# '\nIt is not really possible to find a relationship between table and price\n'

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
clarity = diamonds.groupby('clarity').agg('mean')
clarity
# Out:
#             carat     color      depth      table        price         x  \
# clarity
# 0        1.012202  3.083481  62.630373  58.406572  2669.840142  6.334121
# 1        0.822391  3.699925  61.779639  57.861878  2927.309091  5.918738
# 2        0.657505  3.611845  61.885713  57.602189  2301.057411  5.465231
# 3        0.531536  3.733356  61.725204  57.256663  1758.177647  5.106031
# 4        0.508450  3.317168  61.679757  57.179419  1704.774248  5.040617
# 5        0.432759  3.626382  61.663769  56.958317  1454.187186  4.791229
# 6        0.407424  3.358391  61.626388  56.831628  1381.769495  4.708150
# 7        0.387599  3.036184  61.514145  56.321908  1338.143421  4.654000
#
#                 y         z
# clarity
# 0        6.280835  3.948355
# 1        5.913265  3.653975
# 2        5.467315  3.382279
# 3        5.109989  3.152981
# 4        5.049801  3.111724
# 5        4.805776  2.958090
# 6        4.723260  2.906285
# 7        4.675691  2.868658

# %%
#your comments here
'''
If we just look at clarity we see a negative relationship between the clarity and price.
However, this does not make sense. Therefor, we can assume there is another more important 
indicator for price.
'''
# Out:
# '\nIf we just look at clarity we see a negative relationship between the clarity and price.\nHowever, this does not make sense. Therefor, we can assume there is another more important \nindicator for price.\n'

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
'''
It seems that the amount of carat is the deterministic factor for price. This is different
from my first assumption where I thought that the color of the stone would determine the 
price.
'''

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here
'''
The middle line shows the frequency of rows in the dataset.
You see the same relationship as price and carat with x, y, z and price. 
This could mean that next to carat the size/weight of a diamond is at least or even more 
important than the amount of carat. 
'''

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
'''
In the colored matrix you can clearly see the most important factors on price are carat,
x, y, z'''
# Out:
# '\nIn the colored matrix you can clearly see the most important factors on price are carat,\nx, y, z'

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8911659061637298

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
'''
At first glance it looks like there is a storng correlation between carat and price. 
However, due to the cut of the 75th percentille and higher we do not have enough data 
whether this can be confirmed.
'''

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
'''
Carat has a high standard error of regression meaning the goodness of fit of the model is 
actually quite good, meaning that the result of the regression model would actually be 
accurate.

Another measure of fit would could be checked is the standard error of the regression and 
the coefficients.
'''

# %%
import statsmodels.api as sm

X = diamonds['carat']
y = diamonds['price']

# Note the difference in argument order
model = sm.OLS(y, X).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.940
# Model:                            OLS   Adj. R-squared (uncentered):              0.940
# Method:                 Least Squares   F-statistic:                          6.390e+05
# Date:                Sun, 15 Mar 2020   Prob (F-statistic):                        0.00
# Time:                        20:28:36   Log-Likelihood:                     -3.1623e+05
# No. Observations:               40450   AIC:                                  6.325e+05
# Df Residuals:                   40449   BIC:                                  6.325e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# carat       3687.3209      4.613    799.379      0.000    3678.280    3696.362
# ==============================================================================
# Omnibus:                     5979.318   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9245.098
# Skew:                           1.053   Prob(JB):                         0.00
# Kurtosis:                       4.024   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
