# %%
import pandas as pd

# %%
data = pd.read_csv('ongevallen.txt')

# %%
data.head(60)
# Out:
#      VKL_NUMMER   REGNUMMER PVOPGEM  DATUM_VKL  DAG_CODE  MND_NUMMER  \
# 0   20180004319  2018071654     NaN        NaN       NaN         NaN
# 1   20180004320  2018066468     NaN        NaN       NaN         NaN
# 2   20180004321  2018075557     NaN        NaN       NaN         NaN
# 3   20180004322  2018064629     NaN        NaN       NaN         NaN
# 4   20180004323  2018057657     NaN        NaN       NaN         NaN
# 5   20180004324  2018065202     NaN        NaN       NaN         NaN
# 6   20180004326  2018059121     NaN        NaN       NaN         NaN
# 7   20180047387  2018092733     NaN        NaN       NaN         NaN
# 8   20180004328  2018059593     NaN        NaN       NaN         NaN
# 9   20180047389  2018100278     NaN        NaN       NaN         NaN
# 10  20180047396  2018096825     NaN        NaN       NaN         NaN
# 11  20180004331  2018058845     NaN        NaN       NaN         NaN
# 12  20180004332  2018056173     NaN        NaN       NaN         NaN
# ...

# %%
data.columns
# Out:
# Index(['VKL_NUMMER', 'REGNUMMER', 'PVOPGEM', 'DATUM_VKL', 'DAG_CODE',
#        'MND_NUMMER', 'JAAR_VKL', 'TIJDSTIP', 'UUR', 'DDL_ID', 'AP3_CODE',
#        'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH',
#        'ANTL_GOV', 'ANTL_PTJ', 'ANTL_TDT', 'MNE_CODE', 'AOL_ID', 'NIVEAUKOP',
#        'WSE_ID', 'WSE_AN', 'BEBKOM', 'MAXSNELHD', 'WVL_ID', 'WVG_ID', 'WVG_AN',
#        'WDK_ID', 'WDK_AN', 'LGD_ID', 'ZAD_ID', 'WGD_CODE_1', 'WGD_CODE_2',
#        'BZD_ID_VM1', 'BZD_ID_VM2', 'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1',
#        'BZD_ID_IF2', 'BZD_ID_IF3', 'BZD_IF_AN', 'BZD_ID_TA1', 'BZD_ID_TA2',
#        'BZD_ID_TA3', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID', 'HECTOMETER', 'FK_VELD5',
#        'HUISNUMMER', 'GME_ID', 'GME_NAAM', 'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM',
#        'PLT_NAAM', 'DIENSTCODE', 'DIENSTNAAM', 'DISTRCODE', 'DISTRNAAM',
#        'DAGTYPE', 'IND_ALC', 'WEEKNR'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# VKL_NUMMER         0
# REGNUMMER      28468
# PVOPGEM       128101
# DATUM_VKL     128225
# DAG_CODE      128225
#                ...
# DISTRCODE     105400
# DISTRNAAM     105400
# DAGTYPE       128225
# IND_ALC       125608
# WEEKNR        128225
# Length: 66, dtype: int64
