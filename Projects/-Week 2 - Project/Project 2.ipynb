# %%
# Import modules 
import requests
import json
import pandas as pd

# %%
# Create access to the Amsterdam Waste API
response = requests.get("https://api.data.amsterdam.nl/afval/v1/")
print(response.json())
# Out:
# {'containers': 'https://api.data.amsterdam.nl/afval/v1/containers/', 'wells': 'https://api.data.amsterdam.nl/afval/v1/wells/', 'containertypes': 'https://api.data.amsterdam.nl/afval/v1/containertypes/', 'sites': 'https://api.data.amsterdam.nl/afval/v1/sites/', 'sitefracties': 'https://api.data.amsterdam.nl/afval/v1/sitefracties/'}

# %%
# Access containers API
response = requests.get("https://api.data.amsterdam.nl/afval/v1/containers")
results = response.json()
data = pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-ec09afafddae> in <module>
#       2 response = requests.get("https://api.data.amsterdam.nl/afval/v1/containers")
#       3 results = response.json()
# ----> 4 data = pd.DataFrame(results)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# ...

# %%
# Function to make the JSON more readable 
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

res = jprint(response.json())
# Out:
# {
#     "_links": {
#         "next": {
#             "href": "https://api.data.amsterdam.nl/afval/v1/containers/?page=2"
#         },
#         "previous": {
#             "href": null
#         },
#         "self": {
#             "href": "https://api.data.amsterdam.nl/afval/v1/containers/"
#         }
#     },
#     "count": 14289,
#     "results": [
#         {
#             "_display": "Container object (3888)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/3888/"
#                 }
#             },
#             "active": 1,
#             "address": "Reimerswaalstraat 22, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 3888,
#             "id_number": "REF31196",
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(results)
# Out:
#    count                                            results  \
# 0  14289  [{'_links': {'self': {'href': 'https://api.dat...
#
#                                     _links.self.href  \
# 0  https://api.data.amsterdam.nl/afval/v1/contain...
#
#                                     _links.next.href _links.previous.href
# 0  https://api.data.amsterdam.nl/afval/v1/contain...                 None
