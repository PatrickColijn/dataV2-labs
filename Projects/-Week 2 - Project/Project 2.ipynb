# %%
# Import modules 
import requests
import json
import pandas as pd

# %%
# Import xlsx file
df = pd.read_excel('2019_metropool_325.xlsx')
print (df)
# Out:
#    3.2.5   (On)veiligheidsbeleving naar veiligheidsregio's, 2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                               buurt
# 4           voelt zich wel eens onveilig in buurt (%)
# 5               voelt zich vaak onveilig in buurt (%)
# 6   's avonds op straat in buurt onveilig (% komt ...
# 7   's avonds alleen thuis onveilig (% komt vaak v...
# 8         doet 's avonds niet open (% komt vaak voor)
# 9                rijdt of loopt om (% komt vaak voor)
# 10  bang slachtoffer criminaliteit te worden (% ko...
# 11    denkt dat er veel criminaliteit in buurt is (%)
# 12       vindt criminaliteit in buurt toegenomen (%)
# 13       vindt criminaliteit in buurt afgenomen (%)
# 14  vindt criminaliteit in buurt gelijk gebleven (%)
# 15                 rapportcijfer veiligheid in buurt
# 16  voelt zich wel eens onveilig (%) in de woonplaats
# 17                        rondom uitgaansgelegenheden
# 18                op plekken waar jongeren rondhangen
# 19                          in centrum van woonplaats
# 20                      in winkelgebied/winkelcentrum
# 21                                in openbaar vervoer
# 22                     bij treinstation in woonplaats
# 23                                      in eigen huis
# 24                                           algemeen
# 25                   voelt zich wel eens onveilig (%)
# 26                       voelt zich vaak onveilig (%)
# 27   kans op slachtofferschap (% '(heel) groot') van:
# 28                                    zakkenrollerij
# 29                                beroving op straat
# 30                                  inbraak in woning
# 31                                      mishandeling
# 32  respectloos gedrag (% komt 'wel eens' voor (va...
# 33                               onbekenden op straat
# 34                     onbekenden in openbaar vervoer
# 35                 personeel van winkels en bedrijven
# 36                  personeel van overheidsinstanties
# 37                bekenden (partner, familie, vriend)
# 38                                                NaN
# 39                            RE = Regionale eenheid.
# 40                              PD = Politiedistrict.
#
#         Unnamed: 1         Unnamed: 2                 Unnamed: 3  \
# 0              NaN                NaN                        NaN
# 1   Amsterdam (RE)  Kennemerland (PD)  Zaanstreek-Waterland (PD)
# 2              NaN                NaN                        NaN
# 3              NaN                NaN                        NaN
# 4             22.3               15.7                       15.8
# 5              2.1                1.6                        1.1
# 6              5.1                2.9                        2.4
# 7              2.7                2,0                        2.2
# 8             10.8                8.6                        8.9
# 9              4.3                1.9                        1.3
# 10             4,0                3.4                        3,0
# 11            17.8                7.9                        7.7
# 12            13.2               11.5                       13.3
# 13             7.7                3.7                        2.9
# 14            48.3               52.1                       47.6
# 15             7,0                7.3                        7.3
# 16             NaN                NaN                        NaN
# 17            27.2               21.6                       22.5
# 18            47.1               41.8                       40.9
# 19            22.9               14,0                       15.8
# 20            15.4               12.6                       11.1
# 21            26.6               19.3                       15.1
# 22            25.3               21.4                       19.2
# 23             7.4                7.5                        8,0
# 24             NaN                NaN                        NaN
# 25            39,0               33.4                       33.3
# 26             2.6                2.1                        2,0
# 27             NaN                NaN                        NaN
# 28             6.3                3,0                        4.3
# 29             3.8                1.9                        1.5
# 30            11.7                8.9                        7.9
# 31             3.3                2.2                        1.6
# 32             NaN                NaN                        NaN
# 33            31.2               20.6                       19.2
# 34            22.4               14.3                       12.9
# 35            18.6               14.3                       13.6
# 36            12.1                9.6                       10.8
# 37             6.4                6.4                        6.2
# 38             NaN                NaN                        NaN
# 39             NaN                NaN                        NaN
# 40             NaN                NaN                        NaN
#
#                   Unnamed: 4      Unnamed: 5         Unnamed: 6
# 0                        NaN             NaN                NaN
# 1   Gooi en Vechtstreek (PD)  Flevoland (PD)          Nederland
# 2                        NaN             NaN                NaN
# 3                        NaN             NaN                NaN
# 4                       17,0            19.9               16.4
# 5                        1.4             2.2                1.5
# 6                        3.1             4.5                3.2
# 7                        1.7             3.1                2,0
# 8                        8.3            10.9                8.6
# 9                        1.8             3.5                2.2
# 10                       2.8             4.4                2.7
# 11                      11.1            11.8                9.1
# 12                      15.7            15.3               11.8
# 13                       4.2             5.2                4.2
# 14                      51.1            47.6               50.9
# 15                       7.3             7.2                7.3
# 16                       NaN             NaN                NaN
# 17                      25.9            24.9               21.7
# 18                      42.7            43.7               38.8
# 19                      19.7            21.6               15.5
# 20                      15.1            17.6               12,0
# 21                      17.2            22.7               16.7
# 22                      20.6            27,0               16.5
# 23                       7.4             9.4                7.6
# 24                       NaN             NaN                NaN
# 25                      35.3            36.5               34.1
# 26                       1.6             2.4                1.6
# 27                       NaN             NaN                NaN
# 28                       2.9             3.1                3.1
# 29                       2,0             2.9                1.9
# 30                      12.5            12.4                9,0
# 31                       1.9             2.8                2.2
# 32                       NaN             NaN                NaN
# 33                      21.2            21.5               20.1
# 34                      12.5            15.7               12.9
# 35                      14,0            15,0               12.8
# 36                      12.1             9.9               10,0
# 37                       5.3             6.9                6.3
# 38                       NaN             NaN                NaN
# 39                       NaN             NaN  bron: CBS/VM 2017
# 40                       NaN             NaN                NaN

# %%
response = requests.get("https://api.data.amsterdam.nl/afval/v1/")
print(response)
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'containers': 'https://api.data.amsterdam.nl/afval/v1/containers/', 'wells': 'https://api.data.amsterdam.nl/afval/v1/wells/', 'containertypes': 'https://api.data.amsterdam.nl/afval/v1/containertypes/', 'sites': 'https://api.data.amsterdam.nl/afval/v1/sites/', 'sitefracties': 'https://api.data.amsterdam.nl/afval/v1/sitefracties/'}

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "containers": "https://api.data.amsterdam.nl/afval/v1/containers/",
#     "containertypes": "https://api.data.amsterdam.nl/afval/v1/containertypes/",
#     "sitefracties": "https://api.data.amsterdam.nl/afval/v1/sitefracties/",
#     "sites": "https://api.data.amsterdam.nl/afval/v1/sites/",
#     "wells": "https://api.data.amsterdam.nl/afval/v1/wells/"
# }

# %%
response = requests.get("https://api.data.amsterdam.nl/afval/v1/containers")
print(response)
# Out:
# <Response [200]>

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "_links": {
#         "next": {
#             "href": "https://api.data.amsterdam.nl/afval/v1/containers/?page=2"
#         },
#         "previous": {
#             "href": null
#         },
#         "self": {
#             "href": "https://api.data.amsterdam.nl/afval/v1/containers/"
#         }
#     },
#     "count": 14281,
#     "results": [
#         {
#             "_display": "Container object (3888)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/3888/"
#                 }
#             },
#             "active": 1,
#             "address": "Reimerswaalstraat 22, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 3888,
#             "id_number": "REF31196",
#             "operational_date": "2013-02-22T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2013-02-22T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/3887/"
#         },
#         {
#             "_display": "Container object (3890)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/3890/"
#                 }
#             },
#             "active": 1,
#             "address": "Reimerswaalstraat 22, Amsterdam",
#             "container_type": {
#                 "id": 138,
#                 "name": "Nieuw-West papier 5m3",
#                 "volume": 5.0,
#                 "weight": 650
#             },
#             "id": 3890,
#             "id_number": "PAF32018",
#             "operational_date": "2013-06-22T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2013-06-22T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/3889/"
#         },
#         {
#             "_display": "Container object (4046)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4046/"
#                 }
#             },
#             "active": 1,
#             "address": "Blankenbergestraat 14, Amsterdam",
#             "container_type": {
#                 "id": 1994,
#                 "name": "5TV1423R G2 KH BEL PAP TROPL 4/6",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4046,
#             "id_number": "PAF60317",
#             "operational_date": "2010-10-14T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2010-04-30T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/4045/"
#         },
#         {
#             "_display": "Container object (4048)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4048/"
#                 }
#             },
#             "active": 1,
#             "address": "Antwerpenbaan 8, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4048,
#             "id_number": "REF60325",
#             "operational_date": "2011-10-14T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2011-04-30T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/4047/"
#         },
#         {
#             "_display": "Container object (4086)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4086/"
#                 }
#             },
#             "active": 1,
#             "address": "Oudenaardeplantsoen 13, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4086,
#             "id_number": "REF60725",
#             "operational_date": "2010-10-14T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2010-10-14T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/4085/"
#         },
#         {
#             "_display": "Container object (4864)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4864/"
#                 }
#             },
#             "active": 1,
#             "address": "Senecastraat 32, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4864,
#             "id_number": "SR31448",
#             "operational_date": "2015-07-06T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2007-06-30T00:00:00Z",
#             "warranty_date": "2015-07-06T00:00:00Z",
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/27488/"
#         },
#         {
#             "_display": "Container object (4948)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4948/"
#                 }
#             },
#             "active": 1,
#             "address": "Pieter Calandlaan 169, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4948,
#             "id_number": "REF31420",
#             "operational_date": "2011-06-25T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2011-06-25T00:00:00Z",
#             "warranty_date": "2020-06-25T00:00:00Z",
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/4947/"
#         },
#         {
#             "_display": "Container object (4950)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4950/"
#                 }
#             },
#             "active": 1,
#             "address": "Pieter Calandlaan 169, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4950,
#             "id_number": "REF31419",
#             "operational_date": "2011-06-25T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2011-06-25T00:00:00Z",
#             "warranty_date": "2012-06-25T00:00:00Z",
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/4949/"
#         },
#         {
#             "_display": "Container object (4986)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4986/"
#                 }
#             },
#             "active": 0,
#             "address": "Rijswijkstraat 175, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4986,
#             "id_number": "REF31049",
#             "operational_date": "2014-12-30T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2014-12-30T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/74272/"
#         },
#         {
#             "_display": "Container object (4990)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4990/"
#                 }
#             },
#             "active": 0,
#             "address": "Rijswijkstraat 175, Amsterdam",
#             "container_type": {
#                 "id": 27,
#                 "name": "Nieuw-West (SV)  Rest 5m3 TR Opl inst",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4990,
#             "id_number": "REF31050",
#             "operational_date": "2014-12-30T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2014-12-30T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/26677/"
#         },
#         {
#             "_display": "Container object (4992)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/4992/"
#                 }
#             },
#             "active": 0,
#             "address": "Rijswijkstraat 175, Amsterdam",
#             "container_type": {
#                 "id": 1994,
#                 "name": "5TV1423R G2 KH BEL PAP TROPL 4/6",
#                 "volume": 5.0,
#                 "weight": 700
#             },
#             "id": 4992,
#             "id_number": "PAF32049",
#             "operational_date": "2014-12-29T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2014-12-29T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/26676/"
#         },
#         {
#             "_display": "Container object (6272)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/6272/"
#                 }
#             },
#             "active": 1,
#             "address": "Fogostraat 1, 1060 Amsterdam, Nederland",
#             "container_type": {
#                 "id": 140,
#                 "name": "Algemene order",
#                 "volume": 0.0,
#                 "weight": 0
#             },
#             "id": 6272,
#             "id_number": "Algemeneorder",
#             "operational_date": "2011-10-10T00:00:00Z",
#             "owner": {
#                 "id": 16,
#                 "name": "F Nieuw-West"
#             },
#             "placing_date": "2011-10-10T00:00:00Z",
#             "warranty_date": null,
#             "waste_name": "Rest",
#             "waste_type": 1,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/6271/"
#         },
#         {
#             "_display": "Container object (7324)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7324/"
#                 }
#             },
#             "active": 1,
#             "address": "Veeteeltstraat 19, Amsterdam",
#             "container_type": {
#                 "id": 3322,
#                 "name": "5m3 KHC Papier Amsterdam Standaard 1380*1380*2690",
#                 "volume": 5.0,
#                 "weight": 630
#             },
#             "id": 7324,
#             "id_number": "PAM60067",
#             "operational_date": "2016-03-18T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2016-03-18T00:00:00Z",
#             "warranty_date": "2023-03-18T00:00:00Z",
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7323/"
#         },
#         {
#             "_display": "Container object (7326)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7326/"
#                 }
#             },
#             "active": 1,
#             "address": "Sikkelstraat 21, Amsterdam",
#             "container_type": {
#                 "id": 344,
#                 "name": "Oost stadsdeel KHDC papier 5M3",
#                 "volume": 5.0,
#                 "weight": 600
#             },
#             "id": 7326,
#             "id_number": "PAM60065",
#             "operational_date": "2008-01-01T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2008-01-01T00:00:00Z",
#             "warranty_date": "2015-01-01T00:00:00Z",
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7325/"
#         },
#         {
#             "_display": "Container object (7328)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7328/"
#                 }
#             },
#             "active": 1,
#             "address": "Zuivelplein 9, Amsterdam",
#             "container_type": {
#                 "id": 344,
#                 "name": "Oost stadsdeel KHDC papier 5M3",
#                 "volume": 5.0,
#                 "weight": 600
#             },
#             "id": 7328,
#             "id_number": "PAM60071",
#             "operational_date": "2012-03-29T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2012-03-29T00:00:00Z",
#             "warranty_date": "2019-03-29T00:00:00Z",
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7327/"
#         },
#         {
#             "_display": "Container object (7330)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7330/"
#                 }
#             },
#             "active": 1,
#             "address": "Egstraat 37, Amsterdam",
#             "container_type": {
#                 "id": 3322,
#                 "name": "5m3 KHC Papier Amsterdam Standaard 1380*1380*2690",
#                 "volume": 5.0,
#                 "weight": 630
#             },
#             "id": 7330,
#             "id_number": "PAM60061",
#             "operational_date": "2017-07-27T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2017-07-27T00:00:00Z",
#             "warranty_date": "2024-07-27T00:00:00Z",
#             "waste_name": "Papier",
#             "waste_type": 6,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7329/"
#         },
#         {
#             "_display": "Container object (7342)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7342/"
#                 }
#             },
#             "active": 1,
#             "address": "Veeteeltstraat 19, Amsterdam",
#             "container_type": {
#                 "id": 3323,
#                 "name": "5m3 KHC Glas Amsterdam Standaard 1380*1380*2690",
#                 "volume": 5.0,
#                 "weight": 630
#             },
#             "id": 7342,
#             "id_number": "GLM70045",
#             "operational_date": "2016-03-18T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2016-03-18T00:00:00Z",
#             "warranty_date": "2023-03-18T00:00:00Z",
#             "waste_name": "Glas",
#             "waste_type": 2,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7341/"
#         },
#         {
#             "_display": "Container object (7344)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7344/"
#                 }
#             },
#             "active": 1,
#             "address": "Sikkelstraat 63, Amsterdam",
#             "container_type": {
#                 "id": 333,
#                 "name": "Oost stadsdeel KHDC Glas 1 4m3",
#                 "volume": 4.0,
#                 "weight": 500
#             },
#             "id": 7344,
#             "id_number": "GLM70044",
#             "operational_date": "2008-01-01T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2008-01-01T00:00:00Z",
#             "warranty_date": "2015-01-01T00:00:00Z",
#             "waste_name": "Glas",
#             "waste_type": 2,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7343/"
#         },
#         {
#             "_display": "Container object (7346)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7346/"
#                 }
#             },
#             "active": 1,
#             "address": "Zuivelplein 9, Amsterdam",
#             "container_type": {
#                 "id": 333,
#                 "name": "Oost stadsdeel KHDC Glas 1 4m3",
#                 "volume": 4.0,
#                 "weight": 500
#             },
#             "id": 7346,
#             "id_number": "GLM70049",
#             "operational_date": "2012-03-29T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2012-03-29T00:00:00Z",
#             "warranty_date": "2019-03-29T00:00:00Z",
#             "waste_name": "Glas",
#             "waste_type": 2,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7345/"
#         },
#         {
#             "_display": "Container object (7348)",
#             "_links": {
#                 "self": {
#                     "href": "https://api.data.amsterdam.nl/afval/v1/containers/7348/"
#                 }
#             },
#             "active": 1,
#             "address": "Egstraat 33, Amsterdam",
#             "container_type": {
#                 "id": 3323,
#                 "name": "5m3 KHC Glas Amsterdam Standaard 1380*1380*2690",
#                 "volume": 5.0,
#                 "weight": 630
#             },
#             "id": 7348,
#             "id_number": "GLM70041",
#             "operational_date": "2017-07-27T00:00:00Z",
#             "owner": {
#                 "id": 111,
#                 "name": "M Oost"
#             },
#             "placing_date": "2017-07-27T00:00:00Z",
#             "warranty_date": "2024-07-27T00:00:00Z",
#             "waste_name": "Glas",
#             "waste_type": 2,
#             "well": "https://api.data.amsterdam.nl/afval/v1/wells/7347/"
#         }
#     ]
# }
