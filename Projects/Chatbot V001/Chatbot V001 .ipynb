# %% [markdown]
# # Building a Conversational Chatbot for Slack using Rasa and Python -Part 1

# %% [markdown]
# ## Starting Jupyter Notebook with necessary imports

# %%
# %matplotlib inline

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

# %% [markdown]
# # Installations
# * Rasa NLU
# * Rasa Core
# * SpaCy Language Mode

# %%
import sys
python = sys.executable

# In your environment run:
# !{python} -m pip install -U rasa_core rasa_nlu[spacy];
# Out:
# Requirement already up-to-date: rasa_core in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (0.14.5)
# Requirement already up-to-date: rasa_nlu[spacy] in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (0.15.1)
# Requirement already satisfied, skipping upgrade: typing~=3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.7.4.1)
# Requirement already satisfied, skipping upgrade: ruamel.yaml~=0.15.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.15.100)
# Requirement already satisfied, skipping upgrade: questionary>=1.0.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.5.1)
# Requirement already satisfied, skipping upgrade: flask-jwt-simple~=0.0.3 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.0.3)
# Requirement already satisfied, skipping upgrade: python-telegram-bot~=11.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (11.1.0)
# Requirement already satisfied, skipping upgrade: numpy~=1.16 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.17.2)
# Requirement already satisfied, skipping upgrade: gevent~=1.3 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.4.0)
# Requirement already satisfied, skipping upgrade: jsonschema~=2.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied, skipping upgrade: flask-cors~=3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.0.8)
# Requirement already satisfied, skipping upgrade: tqdm~=4.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (4.31.1)
# Requirement already satisfied, skipping upgrade: mattermostwrapper~=2.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.2)
# Requirement already satisfied, skipping upgrade: redis~=2.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.10.6)
# Requirement already satisfied, skipping upgrade: webexteamssdk~=1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.1.1)
# Requirement already satisfied, skipping upgrade: scikit-learn~=0.20.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.20.4)
# Requirement already satisfied, skipping upgrade: fakeredis~=0.10.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.10.3)
# Requirement already satisfied, skipping upgrade: coloredlogs~=10.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (10.0)
# Requirement already satisfied, skipping upgrade: twilio~=6.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (6.26.3)
# Requirement already satisfied, skipping upgrade: fbmessenger~=5.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (5.6.0)
# Requirement already satisfied, skipping upgrade: rocketchat-API~=0.6.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.6.36)
# Requirement already satisfied, skipping upgrade: tensorflow~=1.13.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.13.2)
# Requirement already satisfied, skipping upgrade: requests~=2.20 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.23.0)
# Requirement already satisfied, skipping upgrade: networkx~=2.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.4)
# Requirement already satisfied, skipping upgrade: pydot~=1.4 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied, skipping upgrade: jsonpickle~=1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3)
# Requirement already satisfied, skipping upgrade: slackclient~=1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3.2)
# Requirement already satisfied, skipping upgrade: pykwalify~=1.7.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.7.0)
# Requirement already satisfied, skipping upgrade: apscheduler~=3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.6.3)
# Requirement already satisfied, skipping upgrade: pika~=0.12.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.12.0)
# Requirement already satisfied, skipping upgrade: rasa-core-sdk~=0.14 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.14.0)
# Requirement already satisfied, skipping upgrade: terminaltables~=3.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.1.0)
# Requirement already satisfied, skipping upgrade: flask~=1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil~=2.7 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz~=2018.9 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2018.9)
# Requirement already satisfied, skipping upgrade: pymongo~=3.7 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.8.0)
# Requirement already satisfied, skipping upgrade: colorclass~=2.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.2.0)
# Requirement already satisfied, skipping upgrade: scipy~=1.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied, skipping upgrade: packaging~=18.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (18.0)
# Requirement already satisfied, skipping upgrade: colorhash~=1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied, skipping upgrade: python-socketio~=3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.1.2)
# Requirement already satisfied, skipping upgrade: klein~=17.10 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (17.10.0)
# Requirement already satisfied, skipping upgrade: future~=0.17.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (0.17.1)
# Requirement already satisfied, skipping upgrade: matplotlib~=2.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (2.2.5)
# Requirement already satisfied, skipping upgrade: simplejson~=3.13 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (3.17.0)
# Requirement already satisfied, skipping upgrade: cloudpickle~=0.6.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (0.6.1)
# Requirement already satisfied, skipping upgrade: boto3~=1.9 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (1.12.12)
# Requirement already satisfied, skipping upgrade: spacy<=2.0.18,>2.0; extra == "spacy" in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (2.0.18)
# Requirement already satisfied, skipping upgrade: sklearn-crfsuite~=0.3.6; extra == "spacy" in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (0.3.6)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<4.0,>=2.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from questionary>=1.0.1->rasa_core) (2.0.10)
# Requirement already satisfied, skipping upgrade: PyJWT in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask-jwt-simple~=0.0.3->rasa_core) (1.7.1)
# Requirement already satisfied, skipping upgrade: cryptography in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from python-telegram-bot~=11.0->rasa_core) (2.7)
# Requirement already satisfied, skipping upgrade: certifi in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from python-telegram-bot~=11.0->rasa_core) (2019.9.11)
# Requirement already satisfied, skipping upgrade: greenlet>=0.4.14 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from gevent~=1.3->rasa_core) (0.4.15)
# Requirement already satisfied, skipping upgrade: Six in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask-cors~=3.0->rasa_core) (1.12.0)
# Requirement already satisfied, skipping upgrade: requests-toolbelt in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from webexteamssdk~=1.0->rasa_core) (0.9.1)
# Requirement already satisfied, skipping upgrade: humanfriendly>=4.7 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from coloredlogs~=10.0->rasa_core) (8.0)
# Requirement already satisfied, skipping upgrade: pysocks; python_version >= "3.0" in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from twilio~=6.0->rasa_core) (1.7.1)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (0.8.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (3.11.3)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (0.2.2)
# Requirement already satisfied, skipping upgrade: absl-py>=0.1.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (0.9.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.27.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: tensorboard<1.14.0,>=1.13.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.13.1)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.13.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (1.0.8)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (0.33.6)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (1.24.2)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from networkx~=2.2->rasa_core) (4.4.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.1.4 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from pydot~=1.4->rasa_core) (2.4.2)
# Requirement already satisfied, skipping upgrade: websocket-client<0.55.0,>=0.35 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from slackclient~=1.0->rasa_core) (0.54.0)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.11 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from pykwalify~=1.7.0->rasa_core) (5.1.2)
# Requirement already satisfied, skipping upgrade: docopt>=0.6.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied, skipping upgrade: tzlocal>=1.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from apscheduler~=3.0->rasa_core) (2.0.0)
# Requirement already satisfied, skipping upgrade: setuptools>=0.7 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from apscheduler~=3.0->rasa_core) (41.4.0)
# Requirement already satisfied, skipping upgrade: ConfigArgParse~=0.13.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from rasa-core-sdk~=0.14->rasa_core) (0.13.0)
# Requirement already satisfied, skipping upgrade: click>=5.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.15 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (0.16.0)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (2.10.3)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-engineio>=3.2.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from python-socketio~=3.0->rasa_core) (3.11.2)
# Requirement already satisfied, skipping upgrade: Twisted>=15.5 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from klein~=17.10->rasa_nlu[spacy]) (19.10.0)
# Requirement already satisfied, skipping upgrade: incremental in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from klein~=17.10->rasa_nlu[spacy]) (17.5.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (0.10.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.3.3)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.9.5)
# Requirement already satisfied, skipping upgrade: botocore<1.16.0,>=1.15.12 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (1.15.12)
# Requirement already satisfied, skipping upgrade: preshed<2.1.0,>=2.0.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.1)
# Requirement already satisfied, skipping upgrade: dill<0.3,>=0.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.2.9)
# Requirement already satisfied, skipping upgrade: ujson>=1.35 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.35)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.0.2)
# Requirement already satisfied, skipping upgrade: thinc<6.13.0,>=6.12.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (6.12.1)
# Requirement already satisfied, skipping upgrade: plac<1.0.0,>=0.9.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied, skipping upgrade: regex==2018.01.10 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2018.1.10)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.3)
# Requirement already satisfied, skipping upgrade: python-crfsuite>=0.8.3 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied, skipping upgrade: tabulate in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.8.6)
# Requirement already satisfied, skipping upgrade: wcwidth in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<4.0,>=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.12.3)
# Requirement already satisfied, skipping upgrade: asn1crypto>=0.21.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (3.2.1)
# Requirement already satisfied, skipping upgrade: mock>=2.0.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (3.0.5)
# Requirement already satisfied, skipping upgrade: h5py in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow~=1.13.0->rasa_core) (2.9.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask~=1.0->rasa_core) (1.1.1)
# Requirement already satisfied, skipping upgrade: hyperlink>=17.1.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (19.0.0)
# Requirement already satisfied, skipping upgrade: constantly>=15.1 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (15.1.0)
# Requirement already satisfied, skipping upgrade: Automat>=0.3.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.2.0)
# Requirement already satisfied, skipping upgrade: zope.interface>=4.4.2 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (4.7.1)
# Requirement already satisfied, skipping upgrade: PyHamcrest>=1.9.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (2.0.2)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (19.3.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.12->boto3~=1.9->rasa_nlu[spacy]) (0.15.2)
# Requirement already satisfied, skipping upgrade: msgpack<0.6.0,>=0.5.6 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.5.6)
# Requirement already satisfied, skipping upgrade: cytoolz<0.10,>=0.9.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0.1)
# Requirement already satisfied, skipping upgrade: msgpack-numpy<0.4.4 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.4.3.2)
# Requirement already satisfied, skipping upgrade: wrapt<1.11.0,>=1.10.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.10.11)
# Requirement already satisfied, skipping upgrade: pycparser in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography->python-telegram-bot~=11.0->rasa_core) (2.19)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.10.0)

# %%
# !{python} -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0 in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (2.0.0)
#
#     Linking successful
#     /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/en_core_web_md
#     -->
#     /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %% [markdown]
# ## Downloading the English Language Model

# %%
# !{python} -m spacy link en_core_web_md en --force;
# Out:
#     Linking successful
#     /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/en_core_web_md
#     -->
#     /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %% [markdown]
# # Importing the Installations

# %%
import rasa_nlu
import rasa_core
import spacy

# %% [markdown]
# # 1. Teaching the bot to understand user inputs using Rasa NLU
#
# ## Preparing the NLU Training Data

# %%
nlu_md = """
## intent:greet
- hey
- hello there
- hi
- hello there
- good morning
- good evening
- moin
- hey there
- let's go
- hey dude
- goodmorning
- goodevening
- good afternoon

## intent:goodbye
- cu
- good by
- cee you later
- good night
- good afternoon
- bye
- goodbye
- have a nice day
- see you around
- bye bye
- see you later

## intent:mood_affirm
- yes
- indeed
- of course
- that sounds good
- correct

## intent:mood_deny
- no
- never
- I don't think so
- don't like that
- no way
- not really

## intent:mood_great
- perfect
- very good
- great
- amazing
- feeling like a king
- wonderful
- I am feeling very good
- I am great
- I am amazing
- I am going to save the world
- super
- extremely good
- so so perfect
- so good
- so perfect

## intent:mood_unhappy
- my day was horrible
- I am sad
- I don't feel very well
- I am disappointed
- super sad
- I'm so sad
- sad
- very sad
- unhappy
- bad
- very bad
- awful
- terrible
- not so good
- not very good
- extremly sad
- so saad
- Quite bad - can I get a cute picture of a [bird](group:birds), please?
- Really bad and only [doggo](group:shibes) pics and change that.
- Not good. The only thing that could make me fell better is a picture of a cute [kitten](group:cats).
- so sad. Only the picture of a [puppy](group:shibes) could make it better.
- I am very sad. I need a [cat](group:cats) picture.
- Extremely sad. Only the cute [doggo](group:shibes) pics can make me feel better.
- Bad. Please show me a [bird](group:birds) pic!
- Pretty bad to be honest. Can you show me a [puppy](group:shibes) picture to make me fell better?

## intent: inform
- A [dog](group:shibes)
- [dog](group:shibes)
- [bird](group:birds)
- a [cat](group:cats)
- [cat](group:cats)
- a [bird](group:birds)
- of a [dog](group:shibes)
- of a [cat](group:cats)
- a [bird](group:birds), please
- a [dog](group:shibes), please
"""

# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %% [markdown]
# # Defining the NLU Model Configuration

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"                   # loads the spacy language model
- name: "tokenizer_spacy"             # splits the sentence into tokens
- name: "ner_crf"                   # uses the pretrained spacy NER model
- name: "intent_featurizer_spacy"     # transform the sentence into a vector representation
- name: "intent_classifier_sklearn"   # uses the vector representation to classify using SVM
- name: "ner_synonyms"                # trains the synonyms
""" 

# %store config > config.yml
# Out:
# Writing 'config' (str) to file 'config.yml'.

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 85 (7 distinct intents)
# 	- Found intents: 'inform', 'goodbye', 'mood_unhappy', 'greet', 'mood_deny', 'mood_affirm', 'mood_great'
# 	- entity examples: 18 (1 distinct entities)
# 	- found entities: 'group'
#
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# INFO:rasa_nlu.utils.spacy_utils:Trying to load spacy model with name 'en'
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# INFO:rasa_nlu.model:Starting to train component SpacyNLP
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyTokenizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CRFEntityExtractor
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SklearnIntentClassifier
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.2s finished
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component EntitySynonymMapper
# INFO:rasa_nlu.model:Finished training component.
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# INFO:rasa_nlu.model:Successfully saved model into '/Users/macbook/dataV2-labs/Projects/models/nlu/default/current'

# %% [markdown]
# ## Evaluating the NLU model on a random text

# %%
# A helper function for prettier output

def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("I am very sad. Could you send me a cat picture? "))
# Out:
# {
#   "intent": {
#     "name": "mood_unhappy",
#     "confidence": 0.6410226269696062
#   },
#   "entities": [
#     {
#       "start": 35,
#       "end": 38,
#       "value": "cats",
#       "entity": "group",
#       "confidence": 0.9543162015604569,
#       "extractor": "CRFEntityExtractor",
#       "processors": [
#         "EntitySynonymMapper"
#       ]
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "mood_unhappy",
#       "confidence": 0.6410226269696062
#     },
#     {
#       "name": "goodbye",
#       "confidence": 0.10918827027441855
#     },
#     {
#       "name": "mood_great",
#       "confidence": 0.09930106946218047
#     },
#     {
#       "name": "greet",
#       "confidence": 0.05768743638451059
#     },
#     {
#       "name": "inform",
#       "confidence": 0.034004823927633626
#     },
#     {
#       "name": "mood_affirm",
#       "confidence": 0.03353057501666721
#     },
#     {
#       "name": "mood_deny",
#       "confidence": 0.025265197964983447
#     }
#   ],
#   "text": "I am very sad. Could you send me a cat picture? "
# }

# %% [markdown]
# ## Evaluating the NLU model on a test data
# ### (Here we are using the data at hand i.e nlu.md but it isr recommended to use unseen data)

# %%
from rasa_nlu.test import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 85 (7 distinct intents)
# 	- Found intents: 'inform', 'goodbye', 'mood_unhappy', 'greet', 'mood_deny', 'mood_affirm', 'mood_great'
# 	- entity examples: 18 (1 distinct entities)
# 	- found entities: 'group'
#
# INFO:rasa_nlu.test:Running model for predictions:
# 100%|██████████| 85/85 [00:00<00:00, 132.29it/s]
# INFO:rasa_nlu.test:Intent evaluation results:
# INFO:rasa_nlu.test:Intent Evaluation: Only considering those 85 examples that have a defined intent out of 85 examples
# INFO:rasa_nlu.test:F1-Score:  0.9881730469965763
# INFO:rasa_nlu.test:Precision: 0.9890756302521008
# INFO:rasa_nlu.test:Accuracy:  0.9882352941176471
# INFO:rasa_nlu.test:Classification report:
#               precision    recall  f1-score   support
#
#      goodbye       1.00      0.91      0.95        11
#        greet       0.93      1.00      0.96        13
#       inform       1.00      1.00      1.00        10
#  mood_affirm       1.00      1.00      1.00         5
#    mood_deny       1.00      1.00      1.00         6
#   mood_great       1.00      1.00      1.00        15
# mood_unhappy       1.00      1.00      1.00        25
#
#    micro avg       0.99      0.99      0.99        85
#    macro avg       0.99      0.99      0.99        85
# weighted avg       0.99      0.99      0.99        85
#
# INFO:rasa_nlu.test:Model prediction errors saved to errors.json.
# INFO:rasa_nlu.test:Entity evaluation results:
# INFO:rasa_nlu.test:Evaluation for entity extractor: CRFEntityExtractor
# INFO:rasa_nlu.test:F1-Score:  1.0
# INFO:rasa_nlu.test:Precision: 1.0
# INFO:rasa_nlu.test:Accuracy:  1.0
# INFO:rasa_nlu.test:Classification report:
#               precision    recall  f1-score   support
#
#        group       1.00      1.00      1.00        18
#    no_entity       1.00      1.00      1.00       265
#
#    micro avg       1.00      1.00      1.00       283
#    macro avg       1.00      1.00      1.00       283
# weighted avg       1.00      1.00      1.00       283
# {'intent_evaluation': {'predictions': [{'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.6100184030407697},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5059332984288191},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.6438979894288671},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5059332984288191},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5394322521259962},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5385969731121552},
#    {'text': 'moin',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5258913869740606},
#    {'text': 'hey there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5025940468321921},
#    {'text': "let's go",
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.4930591395394676},
#    {'text': 'hey dude',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.527583875954742},
#    {'text': 'goodmorning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5834482251554886},
#    {'text': 'goodevening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5022227485716448},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5305035880333444},
#    {'text': 'cu',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.48203969468898544},
#    {'text': 'good by',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.49442393115728234},
#    {'text': 'cee you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4622322156375993},
#    {'text': 'good night',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4887792056666702},
#    {'text': 'good afternoon',
#     'intent': 'goodbye',
#     'predicted': 'greet',
#     'confidence': 0.5305035880333444},
#    {'text': 'bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.5441403996604272},
#    {'text': 'goodbye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.5178906713118697},
#    {'text': 'have a nice day',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.48613940258535765},
#    {'text': 'see you around',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4558702794425165},
#    {'text': 'bye bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.5441403996604272},
#    {'text': 'see you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.46541606890952864},
#    {'text': 'yes',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8663671486375539},
#    {'text': 'indeed',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8986355720733932},
#    {'text': 'of course',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8544006560170304},
#    {'text': 'that sounds good',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8785641649860502},
#    {'text': 'correct',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8780708098235916},
#    {'text': 'no',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.8255727198426802},
#    {'text': 'never',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.6984310817977046},
#    {'text': "I don't think so",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.5666093054556486},
#    {'text': "don't like that",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.608682539777335},
#    {'text': 'no way',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.5305105785605598},
#    {'text': 'not really',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.598847874782004},
#    {'text': 'perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7524182956168816},
#    {'text': 'very good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.6879409664874206},
#    {'text': 'great',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.8258004522125095},
#    {'text': 'amazing',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.8281295382497086},
#    {'text': 'feeling like a king',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.620145227098739},
#    {'text': 'wonderful',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7494701846647279},
#    {'text': 'I am feeling very good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7073596112522251},
#    {'text': 'I am great',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7579382710358592},
#    {'text': 'I am amazing',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7328753496185907},
#    {'text': 'I am going to save the world',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.6186067245580061},
#    {'text': 'super',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.8487627393547129},
#    {'text': 'extremely good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.6883387179838532},
#    {'text': 'so so perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.6803040896501409},
#    {'text': 'so good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.6099885712831367},
#    {'text': 'so perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.7458481708220999},
#    {'text': 'my day was horrible',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.6156735201337127},
#    {'text': 'I am sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.7553886647902464},
#    {'text': "I don't feel very well",
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.49979873490378923},
#    {'text': 'I am disappointed',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.6676391054139762},
#    {'text': 'super sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.7560830439458379},
#    {'text': "I'm so sad",
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.7219275590955386},
#    {'text': 'sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8706888409999627},
#    {'text': 'very sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8546967581747867},
#    {'text': 'unhappy',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8521210051417576},
#    {'text': 'bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8445502730706514},
#    {'text': 'very bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.7848935886352655},
#    {'text': 'awful',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8455212784297965},
#    {'text': 'terrible',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8815806081153887},
#    {'text': 'not so good',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.570706774058467},
#    {'text': 'not very good',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.5787454632091732},
#    {'text': 'extremly sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.8258787792864017},
#    {'text': 'so saad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.6147046171655576},
#    {'text': 'Quite bad - can I get a cute picture of a bird, please?',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.5595882349707515},
#    {'text': 'Really bad and only doggo pics and change that.',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.5935134265960571},
#    {'text': 'Not good. The only thing that could make me fell better is a picture of a cute kitten.',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.5637808850227014},
#    {'text': 'so sad. Only the picture of a puppy could make it better.',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.600458767401685},
#    {'text': 'I am very sad. I need a cat picture.',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.7071997126115404},
#    {'text': 'Extremely sad. Only the cute doggo pics can make me feel better.',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.639660056451662},
#    {'text': 'Bad. Please show me a bird pic!',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.6108985618699535},
#    {'text': 'Pretty bad to be honest. Can you show me a puppy picture to make me fell better?',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.5905033666624442},
#    {'text': 'A dog',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.792322358439852},
#    {'text': 'dog',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9336720660547023},
#    {'text': 'bird',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.910227889257549},
#    {'text': 'a cat',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.7897151530965314},
#    {'text': 'cat',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9308949343332503},
#    {'text': 'a bird',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.7517197500199502},
#    {'text': 'of a dog',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.555170788655436},
#    {'text': 'of a cat',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.5515391156652146},
#    {'text': 'a bird, please',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.5366793337851629},
#    {'text': 'a dog, please',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.5643740209159971}],
#   'report': '              precision    recall  f1-score   support\n\n     goodbye       1.00      0.91      0.95        11\n       greet       0.93      1.00      0.96        13\n      inform       1.00      1.00      1.00        10\n mood_affirm       1.00      1.00      1.00         5\n   mood_deny       1.00      1.00      1.00         6\n  mood_great       1.00      1.00      1.00        15\nmood_unhappy       1.00      1.00      1.00        25\n\n   micro avg       0.99      0.99      0.99        85\n   macro avg       0.99      0.99      0.99        85\nweighted avg       0.99      0.99      0.99        85\n',
#   'precision': 0.9890756302521008,
#   'f1_score': 0.9881730469965763,
#   'accuracy': 0.9882352941176471},
#  'entity_evaluation': {'CRFEntityExtractor': {'report': '              precision    recall  f1-score   support\n\n       group       1.00      1.00      1.00        18\n   no_entity       1.00      1.00      1.00       265\n\n   micro avg       1.00      1.00      1.00       283\n   macro avg       1.00      1.00      1.00       283\nweighted avg       1.00      1.00      1.00       283\n',
#    'precision': 1.0,
#    'f1_score': 1.0,
#    'accuracy': 1.0}}}

# %% [markdown]
# # 2. Teaching the bot to respond using Rasa Core
# ## 1. Writing Stories

# %%
stories_md = """
## happy path               <!-- name of the story - just for debugging -->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_goodbye
  
## sad path 1               <!-- this is already the start of the next story -->
* greet
  - utter_greet             <!-- action the bot should execute -->
* mood_unhappy
  - utter_ask_picture
* inform{"animal":"dog"}  
  - action_retrieve_image
  - utter_did_that_help
* mood_affirm
  - utter_happy

## sad path 2
* greet
  - utter_greet
* mood_unhappy
  - utter_ask_picture
* inform{"group":"cat"}
  - action_retrieve_image
  - utter_did_that_help
* mood_deny
  - utter_goodbye
  
## sad path 3
* greet
  - utter_greet
* mood_unhappy{"group":"puppy"}
  - action_retrieve_image
  - utter_did_that_help
* mood_affirm
  - utter_happy
  
## strange user
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_unclear

## say goodbye
* goodbye
  - utter_goodbye

## fallback
- utter_unclear

"""

# %store stories_md > stories.md
# Out:
# Writing 'stories_md' (str) to file 'stories.md'.

# %% [markdown]
# ## 2. Defining a Domain

# %%
domain_yml = """
intents:
- greet
- goodbye
- mood_affirm
- mood_deny
- mood_great
- mood_unhappy
- inform

slots:
  group:
    type: text
    
entities:
- group

actions:
- utter_greet
- utter_did_that_help
- utter_happy
- utter_goodbye
- utter_unclear
- utter_ask_picture
- __main__.ApiAction

templates:
  utter_greet:
  - text: "Hey! How are you?"

  utter_did_that_help:
  - text: "Did that help you?"

  utter_unclear:
  - text: "I am not sure what you are aiming for."
  
  utter_happy:
  - text: "Great carry on!"

  utter_goodbye:
  - text: "Bye"
  
  utter_ask_picture:
  - text: "To cheer you up, I can show you a cute picture of a dog, cat or a bird. Which one do you choose?"
"""

# %store domain_yml > domain.yml
# Out:
# Writing 'domain_yml' (str) to file 'domain.yml'.

# %% [markdown]
# # Custom Actions

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet
from IPython.core.display import Image, display

import requests

class ApiAction(Action):
    def name(self):
        return "action_retrieve_image"

    def run(self, dispatcher, tracker, domain):
        
        group = tracker.get_slot('group')
        
        r = requests.get('http://shibe.online/api/{}?count=1&urls=true&httpsUrls=true'.format(group))
        response = r.content.decode()
        response = response.replace('["',"")
        response = response.replace('"]',"")
   
        
        #display(Image(response[0], height=550, width=520))
        dispatcher.utter_message("Here is something to cheer you up: {}".format(response))

# %% [markdown]
# # Visualising the Training Data

# %%
# !{python} -m pip install pygraphviz;
# Out:
# /bin/sh: apt-get: command not found
# /bin/sh: breq: command not found
# Requirement already satisfied: pygraphviz in /Users/macbook/opt/anaconda3/lib/python3.7/site-packages (1.3)

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.png", max_history=2)
Image(filename="story_graph.png")
# Out:
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 277.76it/s, # trackers=1]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-fd4ff291b331> in <module>
#       3
#       4 agent = Agent('domain.yml')
# ----> 5 agent.visualize("stories.md", "story_graph.png", max_history=2)
#       6 Image(filename="story_graph.png")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in visualize(self, resource_name, output_file, max_history, nlu_training_data, should_merge_nodes, fontsize)
#     634         visualize_stories(story_steps, self.domain, output_file,
#     635                           max_history, self.interpreter,
# --> 636                           nlu_training_data, should_merge_nodes, fontsize)
#     637
#     638     def _ensure_agent_is_ready(self) -> None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/training/visualization.py in visualize_stories(story_steps, domain, output_file, max_history, interpreter, nlu_training_data, should_merge_nodes, fontsize, silent)
#     533                                    should_merge_nodes,
#     534                                    max_distance=1,
# --> 535                                    fontsize=fontsize)
#     536     return graph
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/training/visualization.py in visualize_neighborhood(current, event_sequences, output_file, max_history, interpreter, nlu_training_data, should_merge_nodes, max_distance, fontsize)
#     447
#     448     if should_merge_nodes:
# --> 449         _merge_equivalent_nodes(graph, max_history)
#     450     _replace_edge_labels_with_nodes(graph, next_node_idx, interpreter,
#     451                                     nlu_training_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/training/visualization.py in _merge_equivalent_nodes(graph, max_history)
#     197                 for j in remaining_node_ids[idx + 1:]:
#     198                     if (graph.has_node(j) and
# --> 199                             _nodes_are_equivalent(graph, i, j, max_history)):
#     200                         # make sure we keep special styles
#     201                         _transfer_style(graph.nodes(data=True)[j],
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/training/visualization.py in _nodes_are_equivalent(graph, node_a, node_b, max_history)
#     138 def _nodes_are_equivalent(graph, node_a, node_b, max_history):
#     139     """Decides if two nodes are equivalent based on their fingerprints."""
# --> 140     return (graph.node[node_a]["label"] == graph.node[node_b]["label"] and
#     141             (_outgoing_edges_are_similar(graph, node_a, node_b) or
#     142              _incoming_edges(graph, node_a) == _incoming_edges(graph, node_b) or
#
# AttributeError: 'MultiDiGraph' object has no attribute 'node'

# %% [markdown]
# # Training a Dialogue Model

# %%
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent

# this will catch predictions the model isn't very certain about
# there is a threshold for the NLU predictions as well as the action predictions
fallback = FallbackPolicy(fallback_action_name="utter_unclear",
                          core_threshold=0.2,
                          nlu_threshold=0.1)

agent = Agent('domain.yml', policies=[MemoizationPolicy(), KerasPolicy(), fallback])

# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md')

agent.train(
    training_data,
    validation_split=0.0,
    epochs=200
)

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 233.48it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 69.53it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 57.18it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'action_retrieve_image' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 57.69it/s, # trackers=12]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-800eccc30f7d> in <module>
#      16     training_data,
#      17     validation_split=0.0,
# ---> 18     epochs=200
#      19 )
#      20
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in train(self, training_trackers, **kwargs)
#     519         if kwargs.get('epochs') or kwargs.get('max_history') or kwargs.get(
#     520                 'batch_size'):
# --> 521             raise Exception("Passing policy configuration parameters "
#     522                             "to `agent.train(...)` is not supported "
#     523                             "anymore. Specify parameters directly in the "
#
# Exception: Passing policy configuration parameters to `agent.train(...)` is not supported anymore. Specify parameters directly in the policy configuration instead. More info https://legacy-docs.rasa.com/docs/core  /migrations.html

# %%
#Starting the Bot

from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-81686cbf15c2> in <module>
#       2
#       3 from rasa_core.agent import Agent
# ----> 4 agent = Agent.load('models/dialogue', interpreter=model_directory)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in load(cls, path, interpreter, generator, tracker_store, action_endpoint)
#     278                              "instead.".format(path))
#     279
# --> 280         domain = Domain.load(os.path.join(path, "domain.yml"))
#     281         ensemble = PolicyEnsemble.load(path) if path else None
#     282
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/domain.py in load(cls, filename)
#     119             raise Exception(
#     120                 "Failed to load domain specification from '{}'. "
# --> 121                 "File not found!".format(os.path.abspath(filename)))
#     122         return cls.from_yaml(read_file(filename))
#     123
#
# Exception: Failed to load domain specification from '/Users/macbook/dataV2-labs/Projects/models/dialogue/domain.yml'. File not found!

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# yes
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-26-b334fca9fa9e> in <module>
#       4     if a == 'stop':
#       5         break
# ----> 6     responses = agent.handle_message(a)
#       7     for response in responses:
#       8         print(response["text"])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in handle_message(self, message, message_preprocessor, **kwargs)
#     310             return self.handle_text(message,
#     311                                     message_preprocessor=message_preprocessor,
# --> 312                                     **kwargs)
#     313
#     314         def noop(_):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in handle_text(self, text_message, message_preprocessor, output_channel, sender_id)
#     400                           sender_id)
#     401
# --> 402         return self.handle_message(msg, message_preprocessor)
#     403
#     404     def toggle_memoization(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/agent.py in handle_message(self, message, message_preprocessor, **kwargs)
#     320
#     321         processor = self.create_processor(message_preprocessor)
# --> 322         return processor.handle_message(message)
#     323
#     324     # noinspection PyUnusedLocal
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/processor.py in handle_message(self, message)
#      75             return None
#      76
# ---> 77         self._predict_and_execute_next_action(message, tracker)
#      78         # save tracker state to continue conversation from this state
#      79         self._save_tracker(tracker)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/processor.py in _predict_and_execute_next_action(self, message, tracker)
#     296                num_predicted_actions < self.max_number_of_predictions):
#     297             # this actually just calls the policy's method by the same name
# --> 298             action, policy, confidence = self.predict_next_action(tracker)
#     299
#     300             should_predict_another_action = self._run_action(action,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/processor.py in predict_next_action(self, tracker)
#     156         ML to predict the action. Returns the index of the next action."""
#     157
# --> 158         probabilities, policy = self._get_next_action_probabilities(tracker)
#     159
#     160         max_index = int(np.argmax(probabilities))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/processor.py in _get_next_action_probabilities(self, tracker)
#     469
#     470         return self.policy_ensemble.probabilities_using_best_policy(
# --> 471             tracker, self.domain)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/policies/ensemble.py in probabilities_using_best_policy(self, tracker, domain)
#     338
#     339         for i, p in enumerate(self.policies):
# --> 340             probabilities = p.predict_action_probabilities(tracker, domain)
#     341
#     342             if isinstance(tracker.events[-1], ActionExecutionRejected):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/policies/keras_policy.py in predict_action_probabilities(self, tracker, domain)
#     223
#     224         # noinspection PyPep8Naming
# --> 225         X = self.featurizer.create_X([tracker], domain)
#     226
#     227         with self.graph.as_default(), self.session.as_default():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/featurizers.py in create_X(self, trackers, domain)
#     398
#     399         trackers_as_states = self.prediction_states(trackers, domain)
# --> 400         X, _ = self._featurize_states(trackers_as_states)
#     401         return X
#     402
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/featurizers.py in _featurize_states(self, trackers_as_states)
#     322
#     323             story_features = [self.state_featurizer.encode(state)
# --> 324                               for state in tracker_states]
#     325
#     326             features.append(story_features)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/featurizers.py in <listcomp>(.0)
#     322
#     323             story_features = [self.state_featurizer.encode(state)
# --> 324                               for state in tracker_states]
#     325
#     326             features.append(story_features)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rasa_core/featurizers.py in encode(self, state)
#      96
#      97         if not self.num_features:
# ---> 98             raise Exception("BinarySingleStateFeaturizer "
#      99                             "was not prepared "
#     100                             "before encoding.")
#
# Exception: BinarySingleStateFeaturizer was not prepared before encoding.
