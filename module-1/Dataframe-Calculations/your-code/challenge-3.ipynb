# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders` from Ironhack's database into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# your code here
orders = pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
orders2 = orders.groupby(['CustomerID','Country']).agg('sum').sort_values(by='amount_spent', ascending=False)
orders2
# Out:
#                            Unnamed: 0   InvoiceNo      year  month    day  \
# CustomerID Country
# 14646      Netherlands      544561120  1163267611   4182810  14191   6552
# 18102      United Kingdom   138022684   243297801    866723   3746   1261
# 17450      United Kingdom    92683919   188845149    677704   2292    842
# 16446      United Kingdom      929130     1688629      6033     22     11
# 14911      EIRE            1737367680  3196374868  11416155  46220  18930
# ...                               ...         ...       ...    ...    ...
# 17956      United Kingdom      144967      548862      2011      4      1
# 16454      United Kingdom      802063     1142747      4022     20      7
# 14792      United Kingdom      766395     1140006      4022     20     10
# 16738      United Kingdom       90155      543986      2011      2      2
# 13256      United Kingdom      502122      578841      2011     11      5
#
# ...

# %%
VIP = orders2.loc[(orders2['amount_spent'] > orders2.amount_spent.quantile(0.95))]
VIP = VIP.reset_index()

Preferred = orders2.loc[(orders2['amount_spent'] > orders2.amount_spent.quantile(0.75)) & (orders2['amount_spent'] < orders2.amount_spent.quantile(0.95))] 
Preferred = Preferred.reset_index()

print(VIP)
print(Preferred)
# Out:
#      CustomerID         Country  Unnamed: 0   InvoiceNo      year  month  \
# 0         14646     Netherlands   544561120  1163267611   4182810  14191
# 1         18102  United Kingdom   138022684   243297801    866723   3746
# 2         17450  United Kingdom    92683919   188845149    677704   2292
# 3         16446  United Kingdom      929130     1688629      6033     22
# 4         14911            EIRE  1737367680  3196374868  11416155  46220
# ..          ...             ...         ...         ...       ...    ...
# 213       14944  United Kingdom    45316103    95192895    341870   1174
# 214       13209  United Kingdom    85155019   179608591    645518   2266
# 215       13534  United Kingdom    68916671   164792347    595245   1822
# 216       13050  United Kingdom    88073344   223872574    810364   2992
# 217       12720         Germany    90950303   197785584    711849   2760
#
#        day   hour  Quantity  UnitPrice  amount_spent
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
# your code here
vipcount = VIP.groupby('Country').agg('count')
vipcount
# Out:
#                  CustomerID  Unnamed: 0  InvoiceNo  year  month  day  hour  \
# Country
# Australia                 1           1          1     1      1    1     1
# Channel Islands           1           1          1     1      1    1     1
# Cyprus                    1           1          1     1      1    1     1
# Denmark                   1           1          1     1      1    1     1
# EIRE                      2           2          2     2      2    2     2
# Finland                   1           1          1     1      1    1     1
# France                    9           9          9     9      9    9     9
# Germany                  11          11         11    11     11   11    11
# Japan                     2           2          2     2      2    2     2
# Netherlands               1           1          1     1      1    1     1
# Norway                    1           1          1     1      1    1     1
# ...

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
# your code here
preferredcount = Preferred.groupby('Country').agg('count')
preferredcount
# Out:
#                  CustomerID  Unnamed: 0  InvoiceNo  year  month  day  hour  \
# Country
# Australia                 3           3          3     3      3    3     3
# Austria                   1           1          1     1      1    1     1
# Belgium                  11          11         11    11     11   11    11
# Canada                    1           1          1     1      1    1     1
# Channel Islands           3           3          3     3      3    3     3
# Cyprus                    2           2          2     2      2    2     2
# Denmark                   2           2          2     2      2    2     2
# EIRE                      1           1          1     1      1    1     1
# Finland                   4           4          4     4      4    4     4
# France                   20          20         20    20     20   20    20
# Germany                  28          28         28    28     28   28    28
# ...

# %%
Total = orders2.loc[(orders2['amount_spent'] > orders2.amount_spent.quantile(0.75))]
Total = Total.reset_index()

TotalCount = Total.groupby('Country').agg('count')
TotalCount
# Out:
#                  CustomerID  Unnamed: 0  InvoiceNo  year  month  day  hour  \
# Country
# Australia                 4           4          4     4      4    4     4
# Austria                   1           1          1     1      1    1     1
# Belgium                  11          11         11    11     11   11    11
# Canada                    1           1          1     1      1    1     1
# Channel Islands           4           4          4     4      4    4     4
# Cyprus                    3           3          3     3      3    3     3
# Denmark                   3           3          3     3      3    3     3
# EIRE                      3           3          3     3      3    3     3
# Finland                   5           5          5     5      5    5     5
# France                   29          29         29    29     29   29    29
# Germany                  39          39         39    39     39   39    39
# ...
